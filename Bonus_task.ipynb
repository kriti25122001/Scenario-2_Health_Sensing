# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/IITG_assignments/internship/internship" "/content"

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (411 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree /content/internship/
# Out:
# /content/internship/
# ├── Data
# │   ├── AP01
# │   │   ├── Flow - 30-05-2024.txt
# │   │   ├── Flow Events - 30-05-2024.txt
# │   │   ├── Sleep profile - 30-05-2024.txt
# │   │   ├── SPO2 - 30-05-2024.txt
# │   │   └── Thorac - 30-05-2024.txt
# │   ├── AP02
# │   │   ├── Flow  - 30.05.2024.txt
# │   │   ├── Flow Events  - 30.05.2024.txt
# │   │   ├── Sleep profile  - 30.05.2024.txt
# │   │   ├── SPO2  - 30.05.2024.txt
# │   │   └── Thorac  - 30.05.2024.txt
# │   ├── AP03
# │   │   ├── Flow - 29_05_2024.txt
# │   │   ├── Flow Events - 29_05_2024.txt
# │   │   ├── Sleep profile - 29_05_2024.txt
# │   │   ├── SPO2 - 29_05_2024.txt
# │   │   └── Thorac - 29_05_2024.txt
# │   ├── AP04
# │   │   ├── Flow Events - 29.05.2024.txt
# │   │   ├── Flow Signal - 29.05.2024.txt
# │   │   ├── Sleep profile - 29.05.2024.txt
# │   │   ├── SPO2 Signal - 29.05.2024.txt
# │   │   └── Thorac Signal - 29.05.2024.txt
# │   └── AP05
# │       ├── Flow Events - 28.05.2024.txt
# │       ├── Flow Nasal - 28.05.2024.txt
# │       ├── Sleep profile - 28.05.2024.txt
# │       ├── SPO2 - 28.05.2024.txt
# │       └── Thorac Movement - 28.05.2024.txt
# ├── Dataset
# │   ├── breathing_dataset.csv
# │   ├── combined_breathing_dataset.csv
# │   ├── combined_sleep_stage_dataset.csv
# │   └── sleep_stage_dataset.csv
# ├── Processed_Data
# │   ├── AP01
# │   │   ├── filtered_Flow.csv
# │   │   ├── filtered_SPO2.csv
# │   │   ├── filtered_Thorac.csv
# │   │   ├── Flow.csv
# │   │   ├── Flow_Events.csv
# │   │   ├── Flow_Events.txt
# │   │   ├── Flow.txt
# │   │   ├── Sleep_profile.csv
# │   │   ├── Sleep_profile.txt
# │   │   ├── SPO2.csv
# │   │   ├── SPO2.txt
# │   │   ├── Thorac.csv
# │   │   └── Thorac.txt
# │   ├── AP02
# │   │   ├── filtered_Flow.csv
# │   │   ├── filtered_SPO2.csv
# │   │   ├── filtered_Thorac.csv
# │   │   ├── Flow.csv
# │   │   ├── Flow_Events.csv
# │   │   ├── Flow_Events.txt
# │   │   ├── Flow.txt
# │   │   ├── Sleep_profile.csv
# │   │   ├── Sleep_profile.txt
# │   │   ├── SPO2.csv
# │   │   ├── SPO2.txt
# │   │   ├── Thorac.csv
# │   │   └── Thorac.txt
# │   ├── AP03
# │   │   ├── filtered_Flow.csv
# │   │   ├── filtered_SPO2.csv
# │   │   ├── filtered_Thorac.csv
# │   │   ├── Flow.csv
# │   │   ├── Flow_Events.csv
# │   │   ├── Flow_Events.txt
# │   │   ├── Flow.txt
# │   │   ├── Sleep_profile.csv
# │   │   ├── Sleep_profile.txt
# │   │   ├── SPO2.csv
# │   │   ├── SPO2.txt
# │   │   ├── Thorac.csv
# │   │   └── Thorac.txt
# │   ├── AP04
# │   │   ├── filtered_Flow.csv
# │   │   ├── filtered_SPO2.csv
# │   │   ├── filtered_Thorac.csv
# │   │   ├── Flow.csv
# │   │   ├── Flow_Events.csv
# │   │   ├── Flow_Events.txt
# │   │   ├── Flow.txt
# │   │   ├── Sleep_profile.csv
# │   │   ├── Sleep_profile.txt
# │   │   ├── SPO2.csv
# │   │   ├── SPO2.txt
# │   │   ├── Thorac.csv
# │   │   └── Thorac.txt
# │   └── AP05
# │       ├── filtered_Flow.csv
# │       ├── filtered_SPO2.csv
# │       ├── filtered_Thorac.csv
# │       ├── Flow.csv
# │       ├── Flow_Events.csv
# │       ├── Flow_Events.txt
# │       ├── Flow.txt
# │       ├── Sleep_profile.csv
# │       ├── Sleep_profile.txt
# │       ├── SPO2.csv
# │       ├── SPO2.txt
# │       ├── Thorac.csv
# │       └── Thorac.txt
# └── Visualizations
#     ├── AP01_visualization.pdf
#     ├── AP02_visualization.pdf
#     ├── AP03_visualization.pdf
#     ├── AP04_visualization.pdf
#     └── AP05_visualization.pdf
#
# 14 directories, 99 files

# %%
import os
import re
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Unique Opportunity for Raise! [Bonus 5 marks]

# %%
from datetime import timedelta


def create_sleep_stage_dataset(processed_data_path):
    """
    Creates a dataset for sleep stage classification with:
    - 30-second windows with 50% overlap (15s step)
    - Sleep stage labels from Sleep_profile.csv
    - Same respiratory signals as features
    - Handles all data validation and error cases
    """
    processed_data_path = Path(processed_data_path)
    dataset_path = processed_data_path.parent / "Sleep_Stage_Dataset"
    dataset_path.mkdir(exist_ok=True)

    # Initialize combined dataset
    all_windows = []

    # Process each subject from AP01 to AP05
    for subject_id in [f"AP{i:02d}" for i in range(1, 6)]:
        subject_dir = processed_data_path / subject_id
        if not subject_dir.exists():
            print(f"\nSkipping {subject_id} - folder not found")
            continue

        print(f"\nProcessing {subject_id}...")
        try:
            # Load required files with validation
            def load_csv(file):
                path = subject_dir / file
                if not path.exists():
                    raise FileNotFoundError(f"Missing file: {path}")
                return pd.read_csv(path)

            flow = load_csv("filtered_Flow.csv")
            thorac = load_csv("filtered_Thorac.csv")
            sleep_profile = load_csv("Sleep_profile.csv")

            # Convert timestamps with error handling
            def convert_timestamps(df):
                if 'DateTime' in df.columns:
                    df['DateTime'] = pd.to_datetime(df['DateTime'], errors='coerce')
                elif 'Original_Timestamp' in df.columns:
                    df['DateTime'] = pd.to_datetime(df['Original_Timestamp'],
                                                  format='%d.%m.%Y %H:%M:%S,%f',
                                                  errors='coerce')
                return df.dropna(subset=['DateTime'])

            flow = convert_timestamps(flow)
            thorac = convert_timestamps(thorac)
            sleep_profile = convert_timestamps(sleep_profile)

            # Create 30-second windows with 50% overlap (15s step)
            min_time = max(
                flow['DateTime'].min(),
                thorac['DateTime'].min(),
                sleep_profile['DateTime'].min()
            )
            max_time = min(
                flow['DateTime'].max(),
                thorac['DateTime'].max(),
                sleep_profile['DateTime'].max()
            )

            window_size = timedelta(seconds=30)
            step_size = timedelta(seconds=15)
            current_time = min_time

            # Initialize subject-specific data collector
            subject_windows = []

            while current_time + window_size <= max_time:
                window_start = current_time
                window_end = current_time + window_size

                # Get sleep stage for this window
                window_sleep = sleep_profile[
                    (sleep_profile['DateTime'] >= window_start) &
                    (sleep_profile['DateTime'] < window_end)
                ]

                # Use the most frequent sleep stage in the window
                if len(window_sleep) > 0:
                    sleep_stage = window_sleep['Sleep_Stage'].mode()[0]
                else:
                    sleep_stage = "Unknown"

                # Get signal data
                window_flow = flow[
                    (flow['DateTime'] >= window_start) &
                    (flow['DateTime'] < window_end)
                ]
                window_thorac = thorac[
                    (thorac['DateTime'] >= window_start) &
                    (thorac['DateTime'] < window_end)
                ]

                # Only include complete windows
                if len(window_flow) > 0 and len(window_thorac) > 0:
                    # Calculate various features from the signals
                    flow_values = window_flow['Filtered_Flow_Value'].values
                    thorac_values = window_thorac['Filtered_Thoracic_Value'].values

                    subject_windows.append({
                        'subject': subject_id,
                        'window_start': window_start,
                        'window_end': window_end,
                        'flow_mean': np.mean(flow_values),
                        'flow_std': np.std(flow_values),
                        'flow_min': np.min(flow_values),
                        'flow_max': np.max(flow_values),
                        'thoracic_mean': np.mean(thorac_values),
                        'thoracic_std': np.std(thorac_values),
                        'thoracic_min': np.min(thorac_values),
                        'thoracic_max': np.max(thorac_values),
                        'sleep_stage': sleep_stage,
                        'signal_quality': len(window_flow)  # Number of samples as proxy for quality
                    })

                current_time += step_size

            # Add subject data to combined dataset
            if subject_windows:
                all_windows.extend(subject_windows)
                print(f"Processed {len(subject_windows)} windows for {subject_id}")
                print(f"Sleep stage distribution: {pd.Series([x['sleep_stage'] for x in subject_windows]).value_counts().to_dict()}")
            else:
                print(f"No valid windows created for {subject_id}")

        except Exception as e:
            print(f"Error processing {subject_id}: {str(e)}")
            continue

    # Save combined dataset
    if all_windows:
        sleep_stage_df = pd.DataFrame(all_windows)

        # Map sleep stages to standard categories
        stage_mapping = {
            'Wake': 'Wake',
            'N1': 'N1',
            'N2': 'N2',
            'N3': 'N3',
            'REM': 'REM',
            'A': 'Artifact',  # Assuming 'A' stands for artifact
            'Unknown': 'Unknown'
        }
        sleep_stage_df['sleep_stage'] = sleep_stage_df['sleep_stage'].map(stage_mapping)

        # Save the dataset
        output_path = dataset_path / "sleep_stage_classification_dataset.csv"
        sleep_stage_df.to_csv(output_path, index=False)

        print("\nFinal Statistics:")
        print(f"Total subjects processed: {sleep_stage_df['subject'].nunique()}")
        print(f"Total windows created: {len(sleep_stage_df)}")
        print("\nSleep stage distribution across all subjects:")
        print(sleep_stage_df['sleep_stage'].value_counts())

        print(f"\nSaved dataset to: {output_path}")

        return sleep_stage_df
    else:
        print("\nNo valid data processed for any subject")
        return None

processed_data_path = "/content/internship/Processed_Data"
sleep_stage_df = create_sleep_stage_dataset(processed_data_path)
# Out:
# Processing AP01...
# Processed 1821 windows for AP01
# Sleep stage distribution: {'Wake': 1009, 'N2': 356, 'N3': 206, 'N1': 174, 'REM': 76}
#
# Processing AP02...
# Processed 1768 windows for AP02
# Sleep stage distribution: {'N2': 712, 'Wake': 348, 'N3': 310, 'N1': 268, 'REM': 112, 'A': 18}
#
# Processing AP03...
# Processed 1695 windows for AP03
# Sleep stage distribution: {'Wake': 1133, 'N1': 196, 'N2': 192, 'N3': 96, 'REM': 78}
#
# Processing AP04...
# Processed 1930 windows for AP04
# Sleep stage distribution: {'N2': 592, 'Wake': 540, 'N1': 370, 'N3': 230, 'REM': 198}
#
# Processing AP05...
# Processed 1580 windows for AP05
# Sleep stage distribution: {'N2': 590, 'N1': 312, 'Wake': 240, 'N3': 224, 'REM': 186, 'A': 28}
#
# Final Statistics:
# Total subjects processed: 5
# Total windows created: 8794
#
# Sleep stage distribution across all subjects:
# sleep_stage
# Wake        3270
# N2          2442
# N1          1320
# N3          1066
# REM          650
# Artifact      46
# Name: count, dtype: int64
#
# Saved dataset to: /content/internship/Sleep_Stage_Dataset/sleep_stage_classification_dataset.csv

# %%
# !cp -r "/content/internship/Sleep_Stage_Dataset/" "/content/drive/MyDrive/IITG_assignments/internship/internship"

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten, TimeDistributed
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt



# Load the sleep stage dataset
sleep_stage_df = pd.read_csv('/content/internship/Sleep_Stage_Dataset/sleep_stage_classification_dataset.csv')

# Convert datetime columns
sleep_stage_df['window_start'] = pd.to_datetime(sleep_stage_df['window_start'])
sleep_stage_df['window_end'] = pd.to_datetime(sleep_stage_df['window_end'])

# Preprocessing
# Filter out 'Unknown' and 'Artifact' stages
sleep_stage_df = sleep_stage_df[~sleep_stage_df['sleep_stage'].isin(['Unknown', 'Artifact'])]

# Encode sleep stages
stage_order = ['Wake', 'N1', 'N2', 'N3', 'REM']
label_encoder = LabelEncoder()
label_encoder.fit(stage_order)
sleep_stage_df['stage_encoded'] = label_encoder.transform(sleep_stage_df['sleep_stage'])

# Features and labels
numeric_features = ['flow_mean', 'flow_std', 'flow_min', 'flow_max',
                   'thoracic_mean', 'thoracic_std', 'thoracic_min', 'thoracic_max']
X = sleep_stage_df[numeric_features]
y = sleep_stage_df['stage_encoded']
groups = sleep_stage_df['subject'].values

# Standardize numerical features
scaler = StandardScaler()
X[numeric_features] = scaler.fit_transform(X[numeric_features])

# Convert to numpy arrays
X = X.values.astype('float32')
y = y.values

# Reshape data for 1D CNN and Conv-LSTM (samples, timesteps, features)
X_reshaped = X.reshape(X.shape[0], 1, X.shape[1])

# Define Leave-One-Subject-Out cross-validator
logo = LeaveOneGroupOut()

# Initialize dictionaries to store results
results_cnn = {'accuracy': [], 'precision': [], 'recall': [], 'sensitivity': [], 'specificity': []}
# Out:
# /tmp/ipython-input-10-544436746.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numeric_features] = scaler.fit_transform(X[numeric_features])

# %%
# Define model creation functions
def create_1d_cnn(input_shape, num_classes):
    model = Sequential([
        Conv1D(64, kernel_size=1, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=1),
        Conv1D(128, kernel_size=1, activation='relu'),
        MaxPooling1D(pool_size=1),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])
    return model

def calculate_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    num_classes = cm.shape[0]

    metrics = {
        'accuracy': accuracy_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred, average='weighted', zero_division=0),
        'recall': recall_score(y_true, y_pred, average='weighted', zero_division=0),
        'sensitivity': 0,
        'specificity': 0
    }

    # Calculate sensitivity (recall for each class)
    recalls = recall_score(y_true, y_pred, average=None, zero_division=0)
    metrics['sensitivity'] = np.mean(recalls)

    # Calculate specificity
    specificities = []
    for i in range(num_classes):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(cm[:, i]) - cm[i, i]
        specificities.append(tn / (tn + fp))
    metrics['specificity'] = np.mean(specificities)

    return metrics, cm

# %%
# Perform Leave-One-Subject-Out cross-validation
for fold, (train_idx, test_idx) in enumerate(logo.split(X, y, groups)):
    print(f"\n=== Fold {fold+1} - Testing on subject {groups[test_idx[0]]} ===")

    # Split data
    X_train, X_test = X_reshaped[train_idx], X_reshaped[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Get input shape
    input_shape = (X_train.shape[1], X_train.shape[2])
    num_classes = len(np.unique(y))

    # Train and evaluate 1D CNN
    print("\nTraining 1D CNN...")
    cnn_model = create_1d_cnn(input_shape, num_classes)
    cnn_history = cnn_model.fit(X_train, y_train,
                               epochs=20,
                               batch_size=32,
                               validation_split=0.2,
                               verbose=1)

    # Evaluate 1D CNN
    cnn_pred = np.argmax(cnn_model.predict(X_test), axis=1)

    # Calculate metrics
    cnn_metrics, cnn_cm = calculate_metrics(y_test, cnn_pred)

    # Store results
    results_cnn['accuracy'].append(cnn_metrics['accuracy'])
    results_cnn['precision'].append(cnn_metrics['precision'])
    results_cnn['recall'].append(cnn_metrics['recall'])
    results_cnn['sensitivity'].append(cnn_metrics['sensitivity'])
    results_cnn['specificity'].append(cnn_metrics['specificity'])

    # Print metrics
    print(f"\n1D CNN Metrics for fold {fold+1}:")
    print(f"Accuracy: {cnn_metrics['accuracy']:.4f}")
    print(f"Precision: {cnn_metrics['precision']:.4f}")
    print(f"Recall: {cnn_metrics['recall']:.4f}")
    print(f"Sensitivity: {cnn_metrics['sensitivity']:.4f}")
    print(f"Specificity: {cnn_metrics['specificity']:.4f}")
    print("Confusion Matrix:")
    print(cnn_cm)
# Out:
# === Fold 1 - Testing on subject AP01 ===
#
# Training 1D CNN...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4224 - loss: 1.3986 - val_accuracy: 0.1140 - val_loss: 3.6041
# Epoch 2/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5033 - loss: 1.2220 - val_accuracy: 0.1248 - val_loss: 4.3590
# Epoch 3/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5375 - loss: 1.1649 - val_accuracy: 0.1140 - val_loss: 5.4096
# Epoch 4/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5619 - loss: 1.1233 - val_accuracy: 0.1169 - val_loss: 5.5956
# Epoch 5/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5669 - loss: 1.0824 - val_accuracy: 0.1212 - val_loss: 5.8108
# Epoch 6/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5857 - loss: 1.0397 - val_accuracy: 0.1176 - val_loss: 6.0973
# Epoch 7/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5762 - loss: 1.0254 - val_accuracy: 0.1176 - val_loss: 6.3877
# Epoch 8/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6022 - loss: 1.0055 - val_accuracy: 0.1097 - val_loss: 6.6845
# Epoch 9/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6010 - loss: 0.9900 - val_accuracy: 0.1190 - val_loss: 6.4643
# Epoch 10/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6126 - loss: 0.9682 - val_accuracy: 0.1140 - val_loss: 6.6003
# Epoch 11/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6092 - loss: 0.9956 - val_accuracy: 0.1190 - val_loss: 6.6634
# Epoch 12/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6046 - loss: 1.0006 - val_accuracy: 0.1190 - val_loss: 7.3769
# Epoch 13/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6108 - loss: 0.9645 - val_accuracy: 0.1046 - val_loss: 7.5368
# Epoch 14/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5935 - loss: 0.9832 - val_accuracy: 0.1162 - val_loss: 7.6750
# Epoch 15/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6104 - loss: 0.9501 - val_accuracy: 0.1205 - val_loss: 7.9239
# Epoch 16/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6056 - loss: 0.9790 - val_accuracy: 0.1190 - val_loss: 8.0349
# Epoch 17/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6104 - loss: 0.9466 - val_accuracy: 0.1176 - val_loss: 8.7659
# Epoch 18/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6257 - loss: 0.9264 - val_accuracy: 0.1241 - val_loss: 8.1962
# Epoch 19/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6306 - loss: 0.9096 - val_accuracy: 0.1147 - val_loss: 9.0945
# Epoch 20/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 0.9199 - val_accuracy: 0.1046 - val_loss: 9.7699
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# 1D CNN Metrics for fold 1:
# Accuracy: 0.3048
# Precision: 0.2997
# Recall: 0.3048
# Sensitivity: 0.1921
# Specificity: 0.7767
# Confusion Matrix:
# [[ 10  11   6  21 126]
#  [ 54  26   1  28 247]
#  [  2  73   3   7 121]
#  [  0   4   8  25  39]
#  [109 138 198  73 491]]
#
# === Fold 2 - Testing on subject AP02 ===
#
# Training 1D CNN...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4875 - loss: 1.3361 - val_accuracy: 0.0786 - val_loss: 2.2980
# Epoch 2/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5437 - loss: 1.2000 - val_accuracy: 0.0914 - val_loss: 2.5771
# Epoch 3/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5576 - loss: 1.1288 - val_accuracy: 0.1936 - val_loss: 2.4775
# Epoch 4/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5808 - loss: 1.0825 - val_accuracy: 0.1986 - val_loss: 2.4957
# Epoch 5/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5697 - loss: 1.0771 - val_accuracy: 0.1421 - val_loss: 2.7427
# Epoch 6/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5853 - loss: 1.0444 - val_accuracy: 0.1507 - val_loss: 3.1654
# Epoch 7/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5879 - loss: 1.0464 - val_accuracy: 0.1507 - val_loss: 3.2408
# Epoch 8/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5891 - loss: 1.0240 - val_accuracy: 0.1807 - val_loss: 3.1218
# Epoch 9/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5993 - loss: 1.0239 - val_accuracy: 0.2157 - val_loss: 3.1106
# Epoch 10/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6040 - loss: 1.0178 - val_accuracy: 0.1814 - val_loss: 3.4820
# Epoch 11/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6065 - loss: 0.9981 - val_accuracy: 0.1900 - val_loss: 3.7443
# Epoch 12/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6237 - loss: 0.9827 - val_accuracy: 0.1814 - val_loss: 3.8136
# Epoch 13/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6210 - loss: 0.9688 - val_accuracy: 0.1957 - val_loss: 3.7073
# Epoch 14/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6194 - loss: 0.9585 - val_accuracy: 0.1800 - val_loss: 3.4674
# Epoch 15/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6281 - loss: 0.9557 - val_accuracy: 0.1621 - val_loss: 4.4857
# Epoch 16/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6288 - loss: 0.9629 - val_accuracy: 0.1457 - val_loss: 4.3848
# Epoch 17/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6297 - loss: 0.9590 - val_accuracy: 0.1786 - val_loss: 3.8749
# Epoch 18/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6382 - loss: 0.9318 - val_accuracy: 0.1564 - val_loss: 4.1813
# Epoch 19/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6322 - loss: 0.9289 - val_accuracy: 0.1693 - val_loss: 4.4722
# Epoch 20/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6459 - loss: 0.9088 - val_accuracy: 0.1436 - val_loss: 4.7461
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 1D CNN Metrics for fold 2:
# Accuracy: 0.2771
# Precision: 0.2541
# Recall: 0.2771
# Sensitivity: 0.2564
# Specificity: 0.8087
# Confusion Matrix:
# [[  0 126   0   5 137]
#  [  0 100  94  11 507]
#  [  0  40 100   0 170]
#  [  0  21   0   0  91]
#  [  1  44  18   0 285]]
#
# === Fold 3 - Testing on subject AP03 ===
#
# Training 1D CNN...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.3847 - loss: 1.4385 - val_accuracy: 0.0787 - val_loss: 2.2327
# Epoch 2/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4678 - loss: 1.3316 - val_accuracy: 0.0808 - val_loss: 2.3020
# Epoch 3/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4851 - loss: 1.2434 - val_accuracy: 0.1276 - val_loss: 2.1795
# Epoch 4/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4987 - loss: 1.2269 - val_accuracy: 0.1006 - val_loss: 2.9100
# Epoch 5/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5175 - loss: 1.1718 - val_accuracy: 0.0999 - val_loss: 3.1965
# Epoch 6/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5239 - loss: 1.1541 - val_accuracy: 0.1169 - val_loss: 3.4517
# Epoch 7/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5426 - loss: 1.1341 - val_accuracy: 0.1262 - val_loss: 3.4918
# Epoch 8/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5405 - loss: 1.1264 - val_accuracy: 0.1113 - val_loss: 3.3819
# Epoch 9/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5480 - loss: 1.0991 - val_accuracy: 0.1432 - val_loss: 4.2826
# Epoch 10/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5603 - loss: 1.0750 - val_accuracy: 0.1354 - val_loss: 3.7477
# Epoch 11/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5477 - loss: 1.0890 - val_accuracy: 0.1396 - val_loss: 4.2654
# Epoch 12/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5677 - loss: 1.0563 - val_accuracy: 0.1262 - val_loss: 4.7772
# Epoch 13/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5678 - loss: 1.0508 - val_accuracy: 0.1304 - val_loss: 4.7323
# Epoch 14/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5716 - loss: 1.0515 - val_accuracy: 0.1368 - val_loss: 4.8590
# Epoch 15/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5899 - loss: 1.0153 - val_accuracy: 0.1176 - val_loss: 5.6994
# Epoch 16/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5823 - loss: 1.0173 - val_accuracy: 0.1332 - val_loss: 5.0283
# Epoch 17/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5680 - loss: 1.0276 - val_accuracy: 0.1361 - val_loss: 5.6887
# Epoch 18/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6019 - loss: 0.9894 - val_accuracy: 0.1254 - val_loss: 5.5347
# Epoch 19/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6064 - loss: 0.9803 - val_accuracy: 0.1198 - val_loss: 5.0813
# Epoch 20/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5916 - loss: 0.9984 - val_accuracy: 0.1269 - val_loss: 6.0151
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 1D CNN Metrics for fold 3:
# Accuracy: 0.6224
# Precision: 0.5315
# Recall: 0.6224
# Sensitivity: 0.2765
# Specificity: 0.8322
# Confusion Matrix:
# [[  4  27   1   0 164]
#  [  2  96   4   0  90]
#  [  0  53   2   0  41]
#  [  0   1   0   0  77]
#  [ 63  91  26   0 953]]
#
# === Fold 4 - Testing on subject AP04 ===
#
# Training 1D CNN...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.4559 - loss: 1.3754 - val_accuracy: 0.0814 - val_loss: 2.3182
# Epoch 2/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5714 - loss: 1.1327 - val_accuracy: 0.0990 - val_loss: 2.7799
# Epoch 3/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6105 - loss: 1.0440 - val_accuracy: 0.1026 - val_loss: 3.0548
# Epoch 4/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6206 - loss: 0.9999 - val_accuracy: 0.1540 - val_loss: 2.5709
# Epoch 5/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6327 - loss: 0.9809 - val_accuracy: 0.1452 - val_loss: 2.7467
# Epoch 6/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6418 - loss: 0.9451 - val_accuracy: 0.1452 - val_loss: 2.8995
# Epoch 7/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6572 - loss: 0.9226 - val_accuracy: 0.1576 - val_loss: 3.3707
# Epoch 8/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6528 - loss: 0.8975 - val_accuracy: 0.1525 - val_loss: 3.3061
# Epoch 9/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6535 - loss: 0.9021 - val_accuracy: 0.1752 - val_loss: 3.3990
# Epoch 10/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6664 - loss: 0.8714 - val_accuracy: 0.1305 - val_loss: 4.0965
# Epoch 11/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6553 - loss: 0.8876 - val_accuracy: 0.1562 - val_loss: 3.3687
# Epoch 12/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6701 - loss: 0.8685 - val_accuracy: 0.1745 - val_loss: 3.5599
# Epoch 13/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6674 - loss: 0.8550 - val_accuracy: 0.1884 - val_loss: 3.3869
# Epoch 14/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6669 - loss: 0.8529 - val_accuracy: 0.1591 - val_loss: 3.8779
# Epoch 15/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6800 - loss: 0.8476 - val_accuracy: 0.1804 - val_loss: 3.5961
# Epoch 16/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6813 - loss: 0.8238 - val_accuracy: 0.1503 - val_loss: 4.0586
# Epoch 17/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6622 - loss: 0.8436 - val_accuracy: 0.1745 - val_loss: 3.4939
# Epoch 18/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6790 - loss: 0.8118 - val_accuracy: 0.1371 - val_loss: 4.3116
# Epoch 19/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6773 - loss: 0.8163 - val_accuracy: 0.1613 - val_loss: 3.9999
# Epoch 20/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6901 - loss: 0.8223 - val_accuracy: 0.1415 - val_loss: 4.2381
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 1D CNN Metrics for fold 4:
# Accuracy: 0.2389
# Precision: 0.1790
# Recall: 0.2389
# Sensitivity: 0.1688
# Specificity: 0.7907
# Confusion Matrix:
# [[  9  81  28   0 252]
#  [ 35 138  39   0 380]
#  [  2  33   2   0 193]
#  [ 11  65   2   0 120]
#  [ 37 159  32   0 312]]
#
# === Fold 5 - Testing on subject AP05 ===
#
# Training 1D CNN...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4982 - loss: 1.3281 - val_accuracy: 0.1556 - val_loss: 2.0682
# Epoch 2/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5754 - loss: 1.1608 - val_accuracy: 0.1583 - val_loss: 2.0716
# Epoch 3/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6091 - loss: 1.0677 - val_accuracy: 0.1625 - val_loss: 2.2860
# Epoch 4/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6164 - loss: 1.0315 - val_accuracy: 0.1722 - val_loss: 2.1146
# Epoch 5/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6309 - loss: 0.9817 - val_accuracy: 0.1722 - val_loss: 2.3140
# Epoch 6/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6388 - loss: 0.9694 - val_accuracy: 0.1736 - val_loss: 2.3846
# Epoch 7/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6413 - loss: 0.9541 - val_accuracy: 0.1688 - val_loss: 2.4608
# Epoch 8/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6385 - loss: 0.9627 - val_accuracy: 0.1750 - val_loss: 2.2267
# Epoch 9/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6421 - loss: 0.9464 - val_accuracy: 0.1667 - val_loss: 2.4129
# Epoch 10/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6428 - loss: 0.9327 - val_accuracy: 0.1625 - val_loss: 2.5712
# Epoch 11/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6467 - loss: 0.9257 - val_accuracy: 0.1701 - val_loss: 2.5463
# Epoch 12/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6642 - loss: 0.8815 - val_accuracy: 0.1688 - val_loss: 2.4582
# Epoch 13/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6624 - loss: 0.8795 - val_accuracy: 0.1590 - val_loss: 2.8203
# Epoch 14/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6490 - loss: 0.8990 - val_accuracy: 0.1715 - val_loss: 2.5915
# Epoch 15/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6613 - loss: 0.8822 - val_accuracy: 0.1722 - val_loss: 2.6439
# Epoch 16/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6699 - loss: 0.8650 - val_accuracy: 0.1667 - val_loss: 3.0385
# Epoch 17/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6643 - loss: 0.8704 - val_accuracy: 0.1757 - val_loss: 2.6512
# Epoch 18/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6695 - loss: 0.8565 - val_accuracy: 0.1618 - val_loss: 2.5733
# Epoch 19/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6706 - loss: 0.8444 - val_accuracy: 0.1660 - val_loss: 2.7601
# Epoch 20/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6653 - loss: 0.8590 - val_accuracy: 0.1569 - val_loss: 2.6771
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# 1D CNN Metrics for fold 5:
# Accuracy: 0.2094
# Precision: 0.2376
# Recall: 0.2094
# Sensitivity: 0.2119
# Specificity: 0.8054
# Confusion Matrix:
# [[ 11  29   0   0 272]
#  [111 115   0   0 364]
#  [  2  17   0   0 205]
#  [ 76  25   0   0  85]
#  [  8  33   0   0 199]]
#
# === Aggregated Results for 1D CNN ===
# Accuracy: Mean = 0.3305, Std = 0.1495
# Precision: Mean = 0.3004, Std = 0.1218
# Recall: Mean = 0.3305, Std = 0.1495
# Sensitivity: Mean = 0.2211, Std = 0.0399
# Specificity: Mean = 0.8028, Std = 0.0186

# %%
# Calculate and print aggregated results
def print_aggregated_results(results, model_name):
    print(f"\n=== Aggregated Results for {model_name} ===")
    for metric in results:
        values = results[metric]
        print(f"{metric.capitalize()}: Mean = {np.mean(values):.4f}, Std = {np.std(values):.4f}")

print_aggregated_results(results_cnn, "1D CNN")
# Out:
# === Aggregated Results for 1D CNN ===
# Accuracy: Mean = 0.3305, Std = 0.1495
# Precision: Mean = 0.3004, Std = 0.1218
# Recall: Mean = 0.3305, Std = 0.1495
# Sensitivity: Mean = 0.2211, Std = 0.0399
# Specificity: Mean = 0.8028, Std = 0.0186

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten, TimeDistributed, ConvLSTM1D
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt

# %%
# Load the sleep stage dataset
sleep_stage_df = pd.read_csv('/content/internship/Sleep_Stage_Dataset/sleep_stage_classification_dataset.csv')

# Convert datetime columns
sleep_stage_df['window_start'] = pd.to_datetime(sleep_stage_df['window_start'])
sleep_stage_df['window_end'] = pd.to_datetime(sleep_stage_df['window_end'])

# Preprocessing
# Filter out 'Unknown' and 'Artifact' stages
sleep_stage_df = sleep_stage_df[~sleep_stage_df['sleep_stage'].isin(['Unknown', 'Artifact'])]

# Encode sleep stages
stage_order = ['Wake', 'N1', 'N2', 'N3', 'REM']
label_encoder = LabelEncoder()
label_encoder.fit(stage_order)
sleep_stage_df['stage_encoded'] = label_encoder.transform(sleep_stage_df['sleep_stage'])

# Features and labels
numeric_features = ['flow_mean', 'flow_std', 'flow_min', 'flow_max',
                   'thoracic_mean', 'thoracic_std', 'thoracic_min', 'thoracic_max']
X = sleep_stage_df[numeric_features]
y = sleep_stage_df['stage_encoded']
groups = sleep_stage_df['subject'].values

# Standardize numerical features
scaler = StandardScaler()
X[numeric_features] = scaler.fit_transform(X[numeric_features])

# Convert to numpy arrays
X = X.values.astype('float32')
y = y.values

# Reshape data for ConvLSTM (samples, timesteps, features, channels)
# We'll create 5 timesteps by stacking consecutive samples
n_timesteps = 5
n_features = X.shape[1]
n_samples = X.shape[0] - n_timesteps + 1

X_reshaped = np.zeros((n_samples, n_timesteps, n_features))
y_reshaped = np.zeros(n_samples)

for i in range(n_samples):
    X_reshaped[i] = X[i:i+n_timesteps]
    # Use the label from the last timestep
    y_reshaped[i] = y[i+n_timesteps-1]

# Update groups to match new shape
groups = groups[n_timesteps-1:]

# Define Leave-One-Subject-Out cross-validator
logo = LeaveOneGroupOut()

# Initialize dictionaries to store results
results_conv_lstm = {'accuracy': [], 'precision': [], 'recall': [], 'sensitivity': [], 'specificity': []}
# Out:
# /tmp/ipython-input-15-3552024859.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numeric_features] = scaler.fit_transform(X[numeric_features])

# %%
# Define model creation functions
def create_conv_lstm(input_shape, num_classes):
    model = Sequential([
        # ConvLSTM1D layer - input shape: (timesteps, features, channels)
        ConvLSTM1D(64, kernel_size=1, activation='tanh',
                  recurrent_activation='hard_sigmoid',
                  return_sequences=True,
                  input_shape=input_shape),
        # TimeDistributed wrapper for 1D operations
        TimeDistributed(Conv1D(128, kernel_size=1, activation='relu')),
        TimeDistributed(MaxPooling1D(pool_size=1)),
        TimeDistributed(Flatten()),
        LSTM(128, return_sequences=False),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])
    return model

def calculate_metrics(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    num_classes = cm.shape[0]

    metrics = {
        'accuracy': accuracy_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred, average='weighted', zero_division=0),
        'recall': recall_score(y_true, y_pred, average='weighted', zero_division=0),
        'sensitivity': 0,
        'specificity': 0
    }

    # Calculate sensitivity (recall for each class)
    recalls = recall_score(y_true, y_pred, average=None, zero_division=0)
    metrics['sensitivity'] = np.mean(recalls)

    # Calculate specificity
    specificities = []
    for i in range(num_classes):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(cm[:, i]) - cm[i, i]
        specificities.append(tn / (tn + fp))
    metrics['specificity'] = np.mean(specificities)

    return metrics, cm

# %%
# Perform Leave-One-Subject-Out cross-validation
for fold, (train_idx, test_idx) in enumerate(logo.split(X_reshaped, y_reshaped, groups)):
    print(f"\n=== Fold {fold+1} - Testing on subject {groups[test_idx[0]]} ===")

    # Split data
    X_train, X_test = X_reshaped[train_idx], X_reshaped[test_idx]
    y_train, y_test = y_reshaped[train_idx], y_reshaped[test_idx]

    # Get input shape
    input_shape = (X_train.shape[1], X_train.shape[2], 1)  # Adding channel dimension
    num_classes = len(np.unique(y))

    # Train and evaluate ConvLSTM
    print("\nTraining ConvLSTM...")
    conv_lstm_model = create_conv_lstm(input_shape, num_classes)
    conv_lstm_history = conv_lstm_model.fit(X_train, y_train,
                                          epochs=20,
                                          batch_size=32,
                                          validation_split=0.2,
                                          verbose=1)

    # Evaluate ConvLSTM
    conv_lstm_pred = np.argmax(conv_lstm_model.predict(X_test), axis=1)

    # Calculate metrics
    conv_lstm_metrics, conv_lstm_cm = calculate_metrics(y_test, conv_lstm_pred)

    # Store results
    results_conv_lstm['accuracy'].append(conv_lstm_metrics['accuracy'])
    results_conv_lstm['precision'].append(conv_lstm_metrics['precision'])
    results_conv_lstm['recall'].append(conv_lstm_metrics['recall'])
    results_conv_lstm['sensitivity'].append(conv_lstm_metrics['sensitivity'])
    results_conv_lstm['specificity'].append(conv_lstm_metrics['specificity'])

    # Print metrics
    print(f"\nConvLSTM Metrics for fold {fold+1}:")
    print(f"Accuracy: {conv_lstm_metrics['accuracy']:.4f}")
    print(f"Precision: {conv_lstm_metrics['precision']:.4f}")
    print(f"Recall: {conv_lstm_metrics['recall']:.4f}")
    print(f"Sensitivity: {conv_lstm_metrics['sensitivity']:.4f}")
    print(f"Specificity: {conv_lstm_metrics['specificity']:.4f}")
    print("Confusion Matrix:")
    print(conv_lstm_cm)
# Out:
# === Fold 1 - Testing on subject AP01 ===
#
# Training ConvLSTM...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - accuracy: 0.4416 - loss: 1.4030 - val_accuracy: 0.0794 - val_loss: 6.6149
# Epoch 2/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - accuracy: 0.5207 - loss: 1.1513 - val_accuracy: 0.1299 - val_loss: 6.6672
# Epoch 3/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - accuracy: 0.5720 - loss: 1.0480 - val_accuracy: 0.1248 - val_loss: 8.6564
# Epoch 4/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.5895 - loss: 0.9896 - val_accuracy: 0.1017 - val_loss: 9.7806
# Epoch 5/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.6291 - loss: 0.9032 - val_accuracy: 0.1140 - val_loss: 10.1480
# Epoch 6/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 22s 121ms/step - accuracy: 0.6443 - loss: 0.8623 - val_accuracy: 0.1147 - val_loss: 11.3815
# Epoch 7/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - accuracy: 0.6688 - loss: 0.8108 - val_accuracy: 0.1032 - val_loss: 12.2399
# Epoch 8/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 22s 111ms/step - accuracy: 0.6870 - loss: 0.7760 - val_accuracy: 0.1126 - val_loss: 14.1240
# Epoch 9/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.7098 - loss: 0.7282 - val_accuracy: 0.1162 - val_loss: 14.2930
# Epoch 10/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.7245 - loss: 0.6974 - val_accuracy: 0.1198 - val_loss: 14.7281
# Epoch 11/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 108ms/step - accuracy: 0.7343 - loss: 0.6549 - val_accuracy: 0.1118 - val_loss: 15.9913
# Epoch 12/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - accuracy: 0.7537 - loss: 0.6082 - val_accuracy: 0.1147 - val_loss: 17.0936
# Epoch 13/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.7726 - loss: 0.5627 - val_accuracy: 0.1140 - val_loss: 18.0348
# Epoch 14/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - accuracy: 0.7783 - loss: 0.5513 - val_accuracy: 0.1162 - val_loss: 18.3806
# Epoch 15/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.7902 - loss: 0.5070 - val_accuracy: 0.1082 - val_loss: 19.9838
# Epoch 16/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.7993 - loss: 0.4755 - val_accuracy: 0.1140 - val_loss: 21.6498
# Epoch 17/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.8239 - loss: 0.4409 - val_accuracy: 0.1169 - val_loss: 21.9850
# Epoch 18/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.8257 - loss: 0.4366 - val_accuracy: 0.1111 - val_loss: 23.2266
# Epoch 19/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - accuracy: 0.8371 - loss: 0.3964 - val_accuracy: 0.1198 - val_loss: 22.5483
# Epoch 20/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 22s 102ms/step - accuracy: 0.8503 - loss: 0.3638 - val_accuracy: 0.1111 - val_loss: 24.0931
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#
# ConvLSTM Metrics for fold 1:
# Accuracy: 0.3484
# Precision: 0.3165
# Recall: 0.3484
# Sensitivity: 0.1625
# Specificity: 0.7785
# Confusion Matrix:
# [[ 23   3   2   3 143]
#  [ 60  17   0  13 266]
#  [  2  51  11   1 141]
#  [  7   4   6   0  59]
#  [263  49  76  35 582]]
#
# === Fold 2 - Testing on subject AP02 ===
#
# Training ConvLSTM...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 110ms/step - accuracy: 0.5091 - loss: 1.3171 - val_accuracy: 0.0786 - val_loss: 2.2423
# Epoch 2/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.5718 - loss: 1.1138 - val_accuracy: 0.0929 - val_loss: 2.7456
# Epoch 3/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.6147 - loss: 0.9945 - val_accuracy: 0.1651 - val_loss: 3.7474
# Epoch 4/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - accuracy: 0.6145 - loss: 0.9633 - val_accuracy: 0.1287 - val_loss: 4.7354
# Epoch 5/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 103ms/step - accuracy: 0.6366 - loss: 0.9159 - val_accuracy: 0.1315 - val_loss: 4.9728
# Epoch 6/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.6585 - loss: 0.8593 - val_accuracy: 0.1458 - val_loss: 5.4008
# Epoch 7/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.6665 - loss: 0.8357 - val_accuracy: 0.1172 - val_loss: 5.8814
# Epoch 8/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 17s 98ms/step - accuracy: 0.6901 - loss: 0.7848 - val_accuracy: 0.1279 - val_loss: 6.7651
# Epoch 9/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.7202 - loss: 0.7346 - val_accuracy: 0.1387 - val_loss: 7.0248
# Epoch 10/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.7172 - loss: 0.7213 - val_accuracy: 0.0994 - val_loss: 7.7919
# Epoch 11/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - accuracy: 0.7326 - loss: 0.6807 - val_accuracy: 0.1365 - val_loss: 7.8789
# Epoch 12/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.7517 - loss: 0.6391 - val_accuracy: 0.1094 - val_loss: 8.9012
# Epoch 13/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - accuracy: 0.7621 - loss: 0.5901 - val_accuracy: 0.1165 - val_loss: 9.7538
# Epoch 14/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - accuracy: 0.7801 - loss: 0.5673 - val_accuracy: 0.1172 - val_loss: 10.0439
# Epoch 15/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.7897 - loss: 0.5276 - val_accuracy: 0.1308 - val_loss: 10.6161
# Epoch 16/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - accuracy: 0.7853 - loss: 0.5223 - val_accuracy: 0.1194 - val_loss: 11.5681
# Epoch 17/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.8085 - loss: 0.4671 - val_accuracy: 0.1165 - val_loss: 11.9907
# Epoch 18/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.8244 - loss: 0.4515 - val_accuracy: 0.1108 - val_loss: 12.9829
# Epoch 19/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - accuracy: 0.8276 - loss: 0.4131 - val_accuracy: 0.1072 - val_loss: 12.6533
# Epoch 20/20
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 17s 98ms/step - accuracy: 0.8399 - loss: 0.3802 - val_accuracy: 0.1187 - val_loss: 14.1474
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step
#
# ConvLSTM Metrics for fold 2:
# Accuracy: 0.2257
# Precision: 0.2199
# Recall: 0.2257
# Sensitivity: 0.2076
# Specificity: 0.8034
# Confusion Matrix:
# [[  2  71   0   0 195]
#  [  5  69  53  77 508]
#  [ 17  35   8  63 187]
#  [  0   2   1   0 109]
#  [  8  24   0   0 316]]
#
# === Fold 3 - Testing on subject AP03 ===
#
# Training ConvLSTM...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - accuracy: 0.4113 - loss: 1.4352 - val_accuracy: 0.0780 - val_loss: 2.7485
# Epoch 2/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - accuracy: 0.4826 - loss: 1.2540 - val_accuracy: 0.0738 - val_loss: 4.0378
# Epoch 3/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.5437 - loss: 1.1121 - val_accuracy: 0.0745 - val_loss: 4.7799
# Epoch 4/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.5778 - loss: 1.0205 - val_accuracy: 0.0858 - val_loss: 5.6284
# Epoch 5/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - accuracy: 0.6152 - loss: 0.9402 - val_accuracy: 0.0851 - val_loss: 6.0633
# Epoch 6/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.6430 - loss: 0.9014 - val_accuracy: 0.0844 - val_loss: 6.0657
# Epoch 7/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.6513 - loss: 0.8517 - val_accuracy: 0.0986 - val_loss: 5.7984
# Epoch 8/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.6779 - loss: 0.7886 - val_accuracy: 0.0908 - val_loss: 7.3385
# Epoch 9/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.7035 - loss: 0.7437 - val_accuracy: 0.1603 - val_loss: 6.8542
# Epoch 10/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.7214 - loss: 0.6931 - val_accuracy: 0.1106 - val_loss: 7.4603
# Epoch 11/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.7400 - loss: 0.6539 - val_accuracy: 0.1213 - val_loss: 8.5731
# Epoch 12/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.7685 - loss: 0.5911 - val_accuracy: 0.1007 - val_loss: 8.5732
# Epoch 13/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - accuracy: 0.7723 - loss: 0.5688 - val_accuracy: 0.1220 - val_loss: 9.6037
# Epoch 14/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.7997 - loss: 0.5062 - val_accuracy: 0.1128 - val_loss: 9.8902
# Epoch 15/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.7994 - loss: 0.4850 - val_accuracy: 0.1064 - val_loss: 8.5808
# Epoch 16/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - accuracy: 0.8218 - loss: 0.4252 - val_accuracy: 0.1220 - val_loss: 10.5867
# Epoch 17/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 17s 99ms/step - accuracy: 0.8432 - loss: 0.3903 - val_accuracy: 0.0950 - val_loss: 11.1967
# Epoch 18/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - accuracy: 0.8639 - loss: 0.3492 - val_accuracy: 0.1270 - val_loss: 12.1894
# Epoch 19/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - accuracy: 0.8809 - loss: 0.3080 - val_accuracy: 0.1078 - val_loss: 12.0705
# Epoch 20/20
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - accuracy: 0.8745 - loss: 0.3140 - val_accuracy: 0.1014 - val_loss: 13.2518
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
#
# ConvLSTM Metrics for fold 3:
# Accuracy: 0.5233
# Precision: 0.5024
# Recall: 0.5233
# Sensitivity: 0.2438
# Specificity: 0.8199
# Confusion Matrix:
# [[  5  30   0   0 161]
#  [  2  96  17   0  77]
#  [  0  68   0   0  28]
#  [  0  17   0   0  61]
#  [120 210  17   0 786]]
#
# === Fold 4 - Testing on subject AP04 ===
#
# Training ConvLSTM...
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - accuracy: 0.5177 - loss: 1.3109 - val_accuracy: 0.0822 - val_loss: 3.7751
# Epoch 2/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.6259 - loss: 1.0143 - val_accuracy: 0.1247 - val_loss: 3.8775
# Epoch 3/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - accuracy: 0.6507 - loss: 0.9084 - val_accuracy: 0.0983 - val_loss: 4.2551
# Epoch 4/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.6783 - loss: 0.8409 - val_accuracy: 0.1321 - val_loss: 5.0838
# Epoch 5/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 95ms/step - accuracy: 0.6796 - loss: 0.8108 - val_accuracy: 0.1387 - val_loss: 5.5022
# Epoch 6/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - accuracy: 0.6956 - loss: 0.7750 - val_accuracy: 0.1592 - val_loss: 5.9710
# Epoch 7/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.7066 - loss: 0.7488 - val_accuracy: 0.1687 - val_loss: 5.3924
# Epoch 8/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - accuracy: 0.7244 - loss: 0.6763 - val_accuracy: 0.1790 - val_loss: 5.7201
# Epoch 9/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - accuracy: 0.7437 - loss: 0.6625 - val_accuracy: 0.1335 - val_loss: 7.4358
# Epoch 10/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.7440 - loss: 0.6309 - val_accuracy: 0.1306 - val_loss: 8.1735
# Epoch 11/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 19s 91ms/step - accuracy: 0.7485 - loss: 0.5972 - val_accuracy: 0.1541 - val_loss: 7.5699
# Epoch 12/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 17s 99ms/step - accuracy: 0.7770 - loss: 0.5728 - val_accuracy: 0.1335 - val_loss: 9.8677
# Epoch 13/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.7836 - loss: 0.5367 - val_accuracy: 0.1541 - val_loss: 9.0055
# Epoch 14/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.7907 - loss: 0.5025 - val_accuracy: 0.1541 - val_loss: 10.2212
# Epoch 15/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - accuracy: 0.8148 - loss: 0.4511 - val_accuracy: 0.1445 - val_loss: 10.8096
# Epoch 16/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - accuracy: 0.8312 - loss: 0.4160 - val_accuracy: 0.1548 - val_loss: 10.6215
# Epoch 17/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.8332 - loss: 0.4063 - val_accuracy: 0.1533 - val_loss: 11.1814
# Epoch 18/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.8453 - loss: 0.3725 - val_accuracy: 0.1548 - val_loss: 11.2321
# Epoch 19/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - accuracy: 0.8649 - loss: 0.3370 - val_accuracy: 0.1592 - val_loss: 11.2958
# Epoch 20/20
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - accuracy: 0.8650 - loss: 0.3376 - val_accuracy: 0.1423 - val_loss: 11.9330
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
#
# ConvLSTM Metrics for fold 4:
# Accuracy: 0.2736
# Precision: 0.2739
# Recall: 0.2736
# Sensitivity: 0.2072
# Specificity: 0.8082
# Confusion Matrix:
# [[ 67  97  66   4 136]
#  [115 211  76  10 180]
#  [ 46  55   4   4 121]
#  [ 55  78  14   8  43]
#  [ 95 117  88   2 238]]
#
# === Fold 5 - Testing on subject AP05 ===
#
# Training ConvLSTM...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 29s 105ms/step - accuracy: 0.5077 - loss: 1.3301 - val_accuracy: 0.1571 - val_loss: 1.9001
# Epoch 2/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 104ms/step - accuracy: 0.5927 - loss: 1.0763 - val_accuracy: 0.1543 - val_loss: 2.2808
# Epoch 3/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.6485 - loss: 0.9402 - val_accuracy: 0.1536 - val_loss: 2.4368
# Epoch 4/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.6667 - loss: 0.8705 - val_accuracy: 0.1591 - val_loss: 2.4632
# Epoch 5/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 24s 116ms/step - accuracy: 0.6834 - loss: 0.8259 - val_accuracy: 0.1536 - val_loss: 2.4816
# Epoch 6/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 40s 111ms/step - accuracy: 0.6887 - loss: 0.8105 - val_accuracy: 0.1584 - val_loss: 2.8693
# Epoch 7/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.6920 - loss: 0.7696 - val_accuracy: 0.1550 - val_loss: 3.6773
# Epoch 8/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - accuracy: 0.6997 - loss: 0.7522 - val_accuracy: 0.1598 - val_loss: 3.2281
# Epoch 9/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 102ms/step - accuracy: 0.7155 - loss: 0.7004 - val_accuracy: 0.1772 - val_loss: 3.6675
# Epoch 10/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.7291 - loss: 0.6785 - val_accuracy: 0.1981 - val_loss: 2.9429
# Epoch 11/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.7334 - loss: 0.6400 - val_accuracy: 0.1577 - val_loss: 4.2356
# Epoch 12/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.7414 - loss: 0.6287 - val_accuracy: 0.1744 - val_loss: 4.2414
# Epoch 13/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - accuracy: 0.7711 - loss: 0.5635 - val_accuracy: 0.1960 - val_loss: 4.2229
# Epoch 14/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.7794 - loss: 0.5300 - val_accuracy: 0.2092 - val_loss: 5.3326
# Epoch 15/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 99ms/step - accuracy: 0.7926 - loss: 0.5154 - val_accuracy: 0.1807 - val_loss: 5.8111
# Epoch 16/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.8042 - loss: 0.4864 - val_accuracy: 0.1786 - val_loss: 5.5215
# Epoch 17/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.8237 - loss: 0.4327 - val_accuracy: 0.1779 - val_loss: 6.7768
# Epoch 18/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.8363 - loss: 0.4219 - val_accuracy: 0.1946 - val_loss: 5.8958
# Epoch 19/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.8438 - loss: 0.3760 - val_accuracy: 0.1786 - val_loss: 6.9099
# Epoch 20/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - accuracy: 0.8585 - loss: 0.3522 - val_accuracy: 0.1869 - val_loss: 7.3027
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
#
# ConvLSTM Metrics for fold 5:
# Accuracy: 0.2448
# Precision: 0.3422
# Recall: 0.2448
# Sensitivity: 0.2345
# Specificity: 0.8055
# Confusion Matrix:
# [[ 23 123   0   0 166]
#  [ 91 162   7   5 325]
#  [  3  44  15   0 162]
#  [ 65  47   4   6  64]
#  [ 19  45   2   0 174]]

# %%
# Calculate and print aggregated results
def print_aggregated_results(results, model_name):
    print(f"\n=== Aggregated Results for {model_name} ===")
    for metric in results:
        values = results[metric]
        print(f"{metric.capitalize()}: Mean = {np.mean(values):.4f}, Std = {np.std(values):.4f}")

print_aggregated_results(results_conv_lstm, "ConvLSTM")
# Out:
# === Aggregated Results for ConvLSTM ===
# Accuracy: Mean = 0.3232, Std = 0.1084
# Precision: Mean = 0.3310, Std = 0.0952
# Recall: Mean = 0.3232, Std = 0.1084
# Sensitivity: Mean = 0.2111, Std = 0.0283
# Specificity: Mean = 0.8031, Std = 0.0135
